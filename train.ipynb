# %% [markdown]
# # GPU Enable test

# %%
# GPU enable test
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Load dataset from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="4IR3IGoAEGK4VSJoYQHw")
project = rf.workspace("cv2023").project("breadboard-pin")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.101, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to breadboard-pin-4 in yolov8:: 100%|██████████| 170/170 [00:00<00:00, 1933.27it/s]

# %% [markdown]
# # Segmentation

# %%
# !pip install ultralytics

import os
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n-seg.yaml')  # build a new model from YAML
# model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8n-seg.yaml').load('yolov8n.pt')  # build from YAML and transfer weights
model = YOLO('simple-circuit-best.pt')

# Train the model
datapath = os.path.join(os.getcwd(), "breadboard-pin-3", "data.yaml")
model.train(data=datapath, epochs=50, imgsz=640)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.2/585.2 kB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 19.2 MB/s eta 0:00:00
# ...
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
# ...

# %% [markdown]
# # Object detect

# %%
# !pip install ultralytics

from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights


# Train the model
datapath = os.path.join(os.getcwd(), "breadboard-pin-4", "data.yaml")
model.train(data=datapath, epochs=50, imgsz=640)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n.yaml')  # build a new model from YAML
# model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights
model = YOLO('/content/runs/detect/train12/weights/best.pt')

# Train the model
datapath = os.path.join(os.getcwd(), "breadboard-pin-4", "data.yaml")
model.train(data=datapath, epochs=20, imgsz=640, lr0=0.001, cos_lr=True)
# Out:
# Ultralytics YOLOv8.0.101 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Load a model
model = YOLO('/content/runs/detect/train4/weights/best.pt')  # load a custom model

# Predict with the model
results = model(source='/content/breadboard-pin-3/test/images/145F3FF8-44BD-4525-B5B0-FC608060E4E5_jpeg.rf.ac6152a8af322f30665d4f82df9f55ea.jpg', save=True, save_txt=True, boxes=True)  # predict on an image
# Out:
# image 1/1 /content/breadboard-pin-3/test/images/145F3FF8-44BD-4525-B5B0-FC608060E4E5_jpeg.rf.ac6152a8af322f30665d4f82df9f55ea.jpg: 640x640 1 letterA, 2 letterEs, 1 number1, 3 number10s, 6 number15s, 5 number20s, 14.9ms
# Speed: 2.5ms preprocess, 14.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels

# %%
# !pip install ultralytics

from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n.yaml')  # build a new model from YAML
# model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights
model = YOLO('/content/runs/detect/train8/weights/best.pt')

# Train the model
datapath = os.path.join(os.getcwd(), "breadboard-pin-3", "data.yaml")
model.train(data=datapath, epochs=20, imgsz=640, lr0=0.001, cos_lr=True)
# Out:
# Ultralytics YOLOv8.0.101 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
